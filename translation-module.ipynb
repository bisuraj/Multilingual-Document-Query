# %%
# %pip install pdfx
# Out:
# ...
#
# ...

# %%
import pdfx
pdf = pdfx.PDFx(r" C:\SEMESTER-7\NLP\J-Comp\Multilingual-Document-Query\tm.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\SEMESTER-7\NLP\J-Comp\Multilingual-Document-Query\translation-module.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/SEMESTER-7/NLP/J-Comp/Multilingual-Document-Query/translation-module.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import pdfx
# ----> <a href='vscode-notebook-cell:/c%3A/SEMESTER-7/NLP/J-Comp/Multilingual-Document-Query/translation-module.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> pdf = pdfx.PDFx(r"C:\SEMESTER-7\NLP\J-Comp\tm.pdf ")
#
# File c:\Python311\Lib\site-packages\pdfx\__init__.py:122, in PDFx.__init__(self, uri)
#     120 else:
#     121     if not os.path.isfile(uri):
# --> 122         raise FileNotFoundError("Invalid filename and not an url: '%s'" % uri)
#     123     self.fn = os.path.basename(uri)
#     124     self.stream = open(uri, "rb")
#
# ...

# %%
# %pip install reportlab
# Out:
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.9 MB 660.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.9 MB 656.4 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.9 MB 655.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.9 MB 722.1 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/1.9 MB 706.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.9 MB 737.3 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.9 MB 724.0 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/1.9 MB 714.4 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/1.9 MB 708.9 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/1.9 MB 723.4 kB/s eta 0:00:03
#    ------- -------------------------------- 0.4/1.9 MB 716.8 kB/s eta 0:00:03
# ...

# %%
# %pip install easygoogletranslate
# Out:
# ...
#
# ...

# %%
from easygoogletranslate import EasyGoogleTranslate
import pdfx
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.platypus import Spacer
from reportlab.lib.styles import getSampleStyleSheet

# Load PDF and translate text
pdf = pdfx.PDFx(r"C:\SEMESTER-7\NLP\J-Comp\tm.pdf ")
translator = EasyGoogleTranslate(
    source_language='ta',
    target_language='en',
    timeout=10
)
text = pdf.get_text()
translated_text = translator.translate(text)

# Create a PDF file
output_pdf = r"C:\SEMESTER-7\NLP\J-Comp\translated-text.pdf "

# Split translated text into paragraphs
translated_text = translated_text.replace('\n', ' ').strip()
paragraphs = translated_text.split('.')

# Create a PDF with translated text
doc = SimpleDocTemplate(output_pdf, pagesize=letter)
story = []

styles = getSampleStyleSheet()
style = styles["Normal"]

for paragraph in paragraphs:
    p = Paragraph(paragraph, style)
    story.append(p)
    story.append(Spacer(1, 12))

doc.build(story)

print(f"Translated text saved to: {output_pdf}")
# Out:
# Translated text saved to: C:\SEMESTER-7\NLP\J-Comp\translated-text.pdf
